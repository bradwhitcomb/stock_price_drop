# %% [markdown]
# # checking out the restarted updated old yahoo finance python module
# https://github.com/ranaroussi/yfinance
# https://towardsdatascience.com/best-5-free-stock-market-apis-in-2019-ad91dddec984

# %%
import yfinance as yf
import pandas as pd
from collections import defaultdict
# methods = info

# %%
equity = yf.Ticker("lulu")

# %% [markdown]
# ### model of dictionary we want to create

# %%
stocks = ['bhp','main','jpm','wfc','jnj','wmt','amzn','msft','vlo','arcc','nke','dis','lulu','cvx']

# %%
investment = {}
for stock in stocks:
    equity = yf.Ticker(stock)
    stock = {"price":equity.info['previousClose'], 
             "200DA":equity.info['twoHundredDayAverage'], 
             "Value":equity.info['enterpriseValue'],
             "50DA":equity.info['fiftyDayAverage'],
             "52WH":equity.info['fiftyTwoWeekHigh'],
             "52WL":equity.info["fiftyTwoWeekLow"]
             
            }
    investment[equity.info["symbol"]]=stock

# %%
investment
# Out:
# {'BHP': {'price': 52.59,
#   '200DA': 51.900726,
#   'Value': 147693846528,
#   '50DA': 50.639427,
#   '52WH': 59.02,
#   '52WL': 45.97},
#  'MAIN': {'price': 43.25,
#   '200DA': 42.334347,
#   'Value': 3750824192,
#   '50DA': 42.841145,
#   '52WH': 44.35,
#   '52WL': 31.95},
#  'JPM': {'price': 134.5,
#   '200DA': 116.95203,
#   'Value': 157298376704,
#   '50DA': 129.56514,
#   '52WH': 135.78,
#   '52WL': 91.11},
#  'WFC': {'price': 53.69,
#   '200DA': 48.6329,
#   'Value': 249894043648,
#   '50DA': 53.186573,
#   '52WH': 54.75,
#   '52WL': 43.02},
#  'JNJ': {'price': 139.99,
#   '200DA': 133.4405,
#   'Value': 381727244288,
#   '50DA': 133.99686,
#   '52WH': 148.59,
#   '52WL': 121},
#  'WMT': {'price': 119.14,
#   '200DA': 114.2542,
#   'Value': 413304193024,
#   '50DA': 119.106,
#   '52WH': 125.38,
#   '52WL': 85.78},
#  'AMZN': {'price': 1739.21,
#   '200DA': 1819.3696,
#   'Value': 899628400640,
#   '50DA': 1769.868,
#   '52WH': 2035.8,
#   '52WL': 1307},
#  'MSFT': {'price': 151.13,
#   '200DA': 138.82826,
#   'Value': 1101902381056,
#   '50DA': 146.97343,
#   '52WH': 152.5,
#   '52WL': 93.96},
#  'VLO': {'price': 94.57,
#   '200DA': 85.19442,
#   'Value': 48054427648,
#   '50DA': 97.83086,
#   '52WH': 101.99,
#   '52WL': 68.81},
#  'ARCC': {'price': 18.85,
#   '200DA': 18.427608,
#   'Value': 14555999232,
#   '50DA': 18.622,
#   '52WH': 19.28,
#   '52WL': 14.5},
#  'NKE': {'price': 97.01,
#   '200DA': 87.703186,
#   'Value': 154021494784,
#   '50DA': 92.295425,
#   '52WH': 97.63,
#   '52WL': 66.53},
#  'DIS': {'price': 146.1,
#   '200DA': 137.93811,
#   'Value': 321685127168,
#   '50DA': 141.052,
#   '52WH': 153.41,
#   '52WL': 100.35},
#  'LULU': {'price': 229.65,
#   '200DA': 192.8637,
#   'Value': 29992554496,
#   '50DA': 213.83858,
#   '52WH': 233.53,
#   '52WL': 110.71},
#  'CVX': {'price': 117.89,
#   '200DA': 119.861374,
#   'Value': 248011309056,
#   '50DA': 118.58572,
#   '52WH': 127.34,
#   '52WL': 100.22}}

# %%
pd.DataFrame(investment).T
# Out:
#         price        200DA         Value         50DA     52WH     52WL
# BHP     52.59    51.900726  1.476938e+11    50.639427    59.02    45.97
# MAIN    43.25    42.334347  3.750824e+09    42.841145    44.35    31.95
# JPM    134.50   116.952030  1.572984e+11   129.565140   135.78    91.11
# WFC     53.69    48.632900  2.498940e+11    53.186573    54.75    43.02
# JNJ    139.99   133.440500  3.817272e+11   133.996860   148.59   121.00
# WMT    119.14   114.254200  4.133042e+11   119.106000   125.38    85.78
# AMZN  1739.21  1819.369600  8.996284e+11  1769.868000  2035.80  1307.00
# MSFT   151.13   138.828260  1.101902e+12   146.973430   152.50    93.96
# VLO     94.57    85.194420  4.805443e+10    97.830860   101.99    68.81
# ARCC    18.85    18.427608  1.455600e+10    18.622000    19.28    14.50
# NKE     97.01    87.703186  1.540215e+11    92.295425    97.63    66.53
# DIS    146.10   137.938110  3.216851e+11   141.052000   153.41   100.35
# LULU   229.65   192.863700  2.999255e+10   213.838580   233.53   110.71
# CVX    117.89   119.861374  2.480113e+11   118.585720   127.34   100.22

# %%
class Investment():
    def __init__(self, symbol):
        self.symbol = symbol
        self.equity = yf.Ticker(self.symbol)
        self.grab_price = self.equity.info['previousClose']

# %%
# import pickle
# for stock in stocks:
#     stock = Investment(stock)
#     price = (stock.grab_price)
#     symbol = stock.symbol
#     print(price)
#     pickling_on = open(f"{symbol}.pickle","wb")
#     pickle.dump(price, pickling_on)
#     pickling_on.close()
#     pickle_off = open(f"{symbol}.pickle","rb")
#     highwater = pickle.load(pickle_off)
#     print(highwater)

# %%
# import pickle
# for stock in stocks:
#     stock = Investment(stock)
#     price = (stock.grab_price)
#     symbol = stock.symbol
#     print(symbol)
    
    
#     pickle_off = open("price.pickle","rb")
#     highwater = pickle.load(pickle_off)
#     if price > highwater:
    
#         pickling_on = open("price.pickle","wb")
#         pickle.dump(price, pickling_on)
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
#     else:
    
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
#         print(f"Last price is {(highwater - price)/highwater:.2%} below the highwater")

# %%
# import pickle
# for stock in stocks:
#     stock = Investment(stock)
#     price = stock.grab_price
#     symbol = stock.symbol
    
#     pickle_off = open(f"{symbol}.pickle","rb")
#     highwater = pickle.load(pickle_off)
#     if price > highwater:
    
#         pickling_on = open(f"{symbol}.pickle","wb")
#         pickle.dump(price, pickling_on)
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
    
#     else:
    
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
#         print(f"Last price is {(highwater - price)/highwater:.2%} below the highwater")
#         print(" ")

# %%
import pickle

for stock in stocks:
    stock = Investment(stock)
    price = stock.grab_price
    symbol = stock.symbol
    hw_dict = {}
    delta_dict = {}
    upperSymbol = symbol.upper()
    print(f"This is the upperSymbol {upperSymbol}")
    print(f"This is the symbol {symbol}")
    
    
    
    with open(f"{symbol}.pickle","rb") as pickle_off:
        highwater = pickle.load(pickle_off)
        
        
        if price > highwater:
    
            with open(f"{symbol}.pickle","wb") as pickling_on:
                pickle.dump(price, pickling_on)
                
            
            
            
            print(f"The previous close for {stock.symbol} is ${price:,.2f}. The highwater mark is ${highwater:,.2f}")
            print(" ")
        else:   
            print(f"The previous close for {stock.symbol} is ${price:,.2f}. The highwater mark is ${highwater:,.2f}")
            print(f"Last price is {(highwater - price)/highwater:.2%} below the highwater mark")
            print(" ")
            
    hw_dict['HWater'] = highwater
    investment[upperSymbol].update( hw_dict )
    delta = (price - highwater) / price
    delta_dict['% change'] = delta
    investment[upperSymbol].update(delta_dict)
# Out:
# This is the upperSymbol BHP
# This is the symbol bhp
# The previous close for bhp is $52.59. The highwater mark is $52.59
# Last price is 0.00% below the highwater mark
#
# This is the upperSymbol MAIN
# This is the symbol main
# The previous close for main is $43.25. The highwater mark is $43.25
# Last price is 0.00% below the highwater mark
#
# This is the upperSymbol JPM
# This is the symbol jpm
# The previous close for jpm is $134.50. The highwater mark is $135.04
# Last price is 0.40% below the highwater mark
#
# This is the upperSymbol WFC
# This is the symbol wfc
# The previous close for wfc is $53.69. The highwater mark is $54.37
# Last price is 1.25% below the highwater mark
#
# This is the upperSymbol JNJ
# This is the symbol jnj
# The previous close for jnj is $139.99. The highwater mark is $140.50
# Last price is 0.36% below the highwater mark
#
# This is the upperSymbol WMT
# This is the symbol wmt
# The previous close for wmt is $119.14. The highwater mark is $119.78
# Last price is 0.53% below the highwater mark
#
# This is the upperSymbol AMZN
# This is the symbol amzn
# The previous close for amzn is $1,739.21. The highwater mark is $1,751.60
# Last price is 0.71% below the highwater mark
#
# This is the upperSymbol MSFT
# This is the symbol msft
# The previous close for msft is $151.13. The highwater mark is $151.75
# Last price is 0.41% below the highwater mark
#
# This is the upperSymbol VLO
# This is the symbol vlo
# The previous close for vlo is $94.57. The highwater mark is $94.57
# Last price is 0.00% below the highwater mark
#
# This is the upperSymbol ARCC
# This is the symbol arcc
# The previous close for arcc is $18.85. The highwater mark is $18.85
# Last price is 0.00% below the highwater mark
#
# This is the upperSymbol NKE
# This is the symbol nke
# The previous close for nke is $97.01. The highwater mark is $97.01
# Last price is 0.00% below the highwater mark
#
# This is the upperSymbol DIS
# This is the symbol dis
# The previous close for dis is $146.10. The highwater mark is $147.66
# Last price is 1.06% below the highwater mark
#
# This is the upperSymbol LULU
# This is the symbol lulu
# The previous close for lulu is $229.65. The highwater mark is $230.88
# Last price is 0.53% below the highwater mark
#
# This is the upperSymbol CVX
# This is the symbol cvx
# The previous close for cvx is $117.89. The highwater mark is $118.01
# Last price is 0.10% below the highwater mark

# %%
hw_dict
# Out:
# {'HWater': 118.01}

# %%
investment
# Out:
# {'BHP': {'price': 52.59,
#   '200DA': 51.900726,
#   'Value': 147693846528,
#   '50DA': 50.639427,
#   '52WH': 59.02,
#   '52WL': 45.97,
#   'HWater': 52.59,
#   '% change': 0.0},
#  'MAIN': {'price': 43.25,
#   '200DA': 42.334347,
#   'Value': 3750824192,
#   '50DA': 42.841145,
#   '52WH': 44.35,
#   '52WL': 31.95,
#   'HWater': 43.25,
#   '% change': 0.0},
#  'JPM': {'price': 134.5,
#   '200DA': 116.95203,
#   'Value': 157298376704,
#   '50DA': 129.56514,
#   '52WH': 135.78,
#   '52WL': 91.11,
#   'HWater': 135.04,
#   '% change': -0.004014869888475777},
#  'WFC': {'price': 53.69,
#   '200DA': 48.6329,
#   'Value': 249894043648,
#   '50DA': 53.186573,
#   '52WH': 54.75,
#   '52WL': 43.02,
#   'HWater': 54.37,
#   '% change': -0.012665300800894017},
#  'JNJ': {'price': 139.99,
#   '200DA': 133.4405,
#   'Value': 381727244288,
#   '50DA': 133.99686,
#   '52WH': 148.59,
#   '52WL': 121,
#   'HWater': 140.5,
#   '% change': -0.003643117365526044},
#  'WMT': {'price': 119.14,
#   '200DA': 114.2542,
#   'Value': 413304193024,
#   '50DA': 119.106,
#   '52WH': 125.38,
#   '52WL': 85.78,
#   'HWater': 119.78,
#   '% change': -0.0053718314587879856},
#  'AMZN': {'price': 1739.21,
#   '200DA': 1819.3696,
#   'Value': 899628400640,
#   '50DA': 1769.868,
#   '52WH': 2035.8,
#   '52WL': 1307,
#   'HWater': 1751.6,
#   '% change': -0.007123924080473245},
#  'MSFT': {'price': 151.13,
#   '200DA': 138.82826,
#   'Value': 1101902381056,
#   '50DA': 146.97343,
#   '52WH': 152.5,
#   '52WL': 93.96,
#   'HWater': 151.75,
#   '% change': -0.004102428372924003},
#  'VLO': {'price': 94.57,
#   '200DA': 85.19442,
#   'Value': 48054427648,
#   '50DA': 97.83086,
#   '52WH': 101.99,
#   '52WL': 68.81,
#   'HWater': 94.57,
#   '% change': 0.0},
#  'ARCC': {'price': 18.85,
#   '200DA': 18.427608,
#   'Value': 14555999232,
#   '50DA': 18.622,
#   '52WH': 19.28,
#   '52WL': 14.5,
#   'HWater': 18.85,
#   '% change': 0.0},
#  'NKE': {'price': 97.01,
#   '200DA': 87.703186,
#   'Value': 154021494784,
#   '50DA': 92.295425,
#   '52WH': 97.63,
#   '52WL': 66.53,
#   'HWater': 97.01,
#   '% change': 0.0},
#  'DIS': {'price': 146.1,
#   '200DA': 137.93811,
#   'Value': 321685127168,
#   '50DA': 141.052,
#   '52WH': 153.41,
#   '52WL': 100.35,
#   'HWater': 147.66,
#   '% change': -0.01067761806981521},
#  'LULU': {'price': 229.65,
#   '200DA': 192.8637,
#   'Value': 29992554496,
#   '50DA': 213.83858,
#   '52WH': 233.53,
#   '52WL': 110.71,
#   'HWater': 230.88,
#   '% change': -0.005355976485956846},
#  'CVX': {'price': 117.89,
#   '200DA': 119.861374,
#   'Value': 248011309056,
#   '50DA': 118.58572,
#   '52WH': 127.34,
#   '52WL': 100.22,
#   'HWater': 118.01,
#   '% change': -0.0010178980405463106}}

# %%
for keys in investment:
    print(investment[keys])
# Out:
# {'price': 52.59, '200DA': 51.900726, 'Value': 147693846528, '50DA': 50.639427, '52WH': 59.02, '52WL': 45.97, 'HWater': 52.59, '% change': 0.0}
# {'price': 43.25, '200DA': 42.334347, 'Value': 3750824192, '50DA': 42.841145, '52WH': 44.35, '52WL': 31.95, 'HWater': 43.25, '% change': 0.0}
# {'price': 134.5, '200DA': 116.95203, 'Value': 157298376704, '50DA': 129.56514, '52WH': 135.78, '52WL': 91.11, 'HWater': 135.04, '% change': -0.004014869888475777}
# {'price': 53.69, '200DA': 48.6329, 'Value': 249894043648, '50DA': 53.186573, '52WH': 54.75, '52WL': 43.02, 'HWater': 54.37, '% change': -0.012665300800894017}
# {'price': 139.99, '200DA': 133.4405, 'Value': 381727244288, '50DA': 133.99686, '52WH': 148.59, '52WL': 121, 'HWater': 140.5, '% change': -0.003643117365526044}
# {'price': 119.14, '200DA': 114.2542, 'Value': 413304193024, '50DA': 119.106, '52WH': 125.38, '52WL': 85.78, 'HWater': 119.78, '% change': -0.0053718314587879856}
# {'price': 1739.21, '200DA': 1819.3696, 'Value': 899628400640, '50DA': 1769.868, '52WH': 2035.8, '52WL': 1307, 'HWater': 1751.6, '% change': -0.007123924080473245}
# {'price': 151.13, '200DA': 138.82826, 'Value': 1101902381056, '50DA': 146.97343, '52WH': 152.5, '52WL': 93.96, 'HWater': 151.75, '% change': -0.004102428372924003}
# {'price': 94.57, '200DA': 85.19442, 'Value': 48054427648, '50DA': 97.83086, '52WH': 101.99, '52WL': 68.81, 'HWater': 94.57, '% change': 0.0}
# {'price': 18.85, '200DA': 18.427608, 'Value': 14555999232, '50DA': 18.622, '52WH': 19.28, '52WL': 14.5, 'HWater': 18.85, '% change': 0.0}
# {'price': 97.01, '200DA': 87.703186, 'Value': 154021494784, '50DA': 92.295425, '52WH': 97.63, '52WL': 66.53, 'HWater': 97.01, '% change': 0.0}
# {'price': 146.1, '200DA': 137.93811, 'Value': 321685127168, '50DA': 141.052, '52WH': 153.41, '52WL': 100.35, 'HWater': 147.66, '% change': -0.01067761806981521}
# {'price': 229.65, '200DA': 192.8637, 'Value': 29992554496, '50DA': 213.83858, '52WH': 233.53, '52WL': 110.71, 'HWater': 230.88, '% change': -0.005355976485956846}
# {'price': 117.89, '200DA': 119.861374, 'Value': 248011309056, '50DA': 118.58572, '52WH': 127.34, '52WL': 100.22, 'HWater': 118.01, '% change': -0.0010178980405463106}

# %%
# def write_to_pickle_file(filename, an_object):
#     with open(filename, 'wb') as file:
#         pickle.dump(an_object, file)

# %%
# def write_to_pickle_file("stockhighwater.pickle", an_object):
#     with open(filename, 'wb') as file:
#         pickle.dump(an_object, file)

# %%
# import pickle
# magic = {1:"A",2:"B",3:"C",4:"D",5:"E"}
# pickling_on = open("Emp.pickle","wb")
# pickle.dump(magic, pickling_on)
# pickling_on.close()

# %%
# pickle_off = open("Emp.pickle","rb")
# magic = pickle.load(pickle_off)
# print(magic)

# %%
pd.DataFrame(investment)
# Out:
#                    BHP          MAIN           JPM           WFC  \
# price     5.259000e+01  4.325000e+01  1.345000e+02  5.369000e+01
# 200DA     5.190073e+01  4.233435e+01  1.169520e+02  4.863290e+01
# Value     1.476938e+11  3.750824e+09  1.572984e+11  2.498940e+11
# 50DA      5.063943e+01  4.284114e+01  1.295651e+02  5.318657e+01
# 52WH      5.902000e+01  4.435000e+01  1.357800e+02  5.475000e+01
# 52WL      4.597000e+01  3.195000e+01  9.111000e+01  4.302000e+01
# HWater    5.259000e+01  4.325000e+01  1.350400e+02  5.437000e+01
# % change  0.000000e+00  0.000000e+00 -4.014870e-03 -1.266530e-02
#
#                    JNJ           WMT          AMZN          MSFT  \
# price     1.399900e+02  1.191400e+02  1.739210e+03  1.511300e+02
# 200DA     1.334405e+02  1.142542e+02  1.819370e+03  1.388283e+02
# Value     3.817272e+11  4.133042e+11  8.996284e+11  1.101902e+12
# 50DA      1.339969e+02  1.191060e+02  1.769868e+03  1.469734e+02
# 52WH      1.485900e+02  1.253800e+02  2.035800e+03  1.525000e+02
# 52WL      1.210000e+02  8.578000e+01  1.307000e+03  9.396000e+01
# HWater    1.405000e+02  1.197800e+02  1.751600e+03  1.517500e+02
# % change -3.643117e-03 -5.371831e-03 -7.123924e-03 -4.102428e-03
#
#                    VLO          ARCC           NKE           DIS  \
# price     9.457000e+01  1.885000e+01  9.701000e+01  1.461000e+02
# 200DA     8.519442e+01  1.842761e+01  8.770319e+01  1.379381e+02
# Value     4.805443e+10  1.455600e+10  1.540215e+11  3.216851e+11
# 50DA      9.783086e+01  1.862200e+01  9.229542e+01  1.410520e+02
# 52WH      1.019900e+02  1.928000e+01  9.763000e+01  1.534100e+02
# 52WL      6.881000e+01  1.450000e+01  6.653000e+01  1.003500e+02
# HWater    9.457000e+01  1.885000e+01  9.701000e+01  1.476600e+02
# % change  0.000000e+00  0.000000e+00  0.000000e+00 -1.067762e-02
#
#                   LULU           CVX
# price     2.296500e+02  1.178900e+02
# 200DA     1.928637e+02  1.198614e+02
# Value     2.999255e+10  2.480113e+11
# 50DA      2.138386e+02  1.185857e+02
# 52WH      2.335300e+02  1.273400e+02
# 52WL      1.107100e+02  1.002200e+02
# HWater    2.308800e+02  1.180100e+02
# % change -5.355976e-03 -1.017898e-03

# %%
investment
# Out:
# {'BHP': {'price': 52.59,
#   '200DA': 51.900726,
#   'Value': 147693846528,
#   '50DA': 50.639427,
#   '52WH': 59.02,
#   '52WL': 45.97,
#   'HWater': 52.59,
#   '% change': 0.0},
#  'MAIN': {'price': 43.25,
#   '200DA': 42.334347,
#   'Value': 3750824192,
#   '50DA': 42.841145,
#   '52WH': 44.35,
#   '52WL': 31.95,
#   'HWater': 43.25,
#   '% change': 0.0},
#  'JPM': {'price': 134.5,
#   '200DA': 116.95203,
#   'Value': 157298376704,
#   '50DA': 129.56514,
#   '52WH': 135.78,
#   '52WL': 91.11,
#   'HWater': 135.04,
#   '% change': -0.004014869888475777},
#  'WFC': {'price': 53.69,
#   '200DA': 48.6329,
#   'Value': 249894043648,
#   '50DA': 53.186573,
#   '52WH': 54.75,
#   '52WL': 43.02,
#   'HWater': 54.37,
#   '% change': -0.012665300800894017},
#  'JNJ': {'price': 139.99,
#   '200DA': 133.4405,
#   'Value': 381727244288,
#   '50DA': 133.99686,
#   '52WH': 148.59,
#   '52WL': 121,
#   'HWater': 140.5,
#   '% change': -0.003643117365526044},
#  'WMT': {'price': 119.14,
#   '200DA': 114.2542,
#   'Value': 413304193024,
#   '50DA': 119.106,
#   '52WH': 125.38,
#   '52WL': 85.78,
#   'HWater': 119.78,
#   '% change': -0.0053718314587879856},
#  'AMZN': {'price': 1739.21,
#   '200DA': 1819.3696,
#   'Value': 899628400640,
#   '50DA': 1769.868,
#   '52WH': 2035.8,
#   '52WL': 1307,
#   'HWater': 1751.6,
#   '% change': -0.007123924080473245},
#  'MSFT': {'price': 151.13,
#   '200DA': 138.82826,
#   'Value': 1101902381056,
#   '50DA': 146.97343,
#   '52WH': 152.5,
#   '52WL': 93.96,
#   'HWater': 151.75,
#   '% change': -0.004102428372924003},
#  'VLO': {'price': 94.57,
#   '200DA': 85.19442,
#   'Value': 48054427648,
#   '50DA': 97.83086,
#   '52WH': 101.99,
#   '52WL': 68.81,
#   'HWater': 94.57,
#   '% change': 0.0},
#  'ARCC': {'price': 18.85,
#   '200DA': 18.427608,
#   'Value': 14555999232,
#   '50DA': 18.622,
#   '52WH': 19.28,
#   '52WL': 14.5,
#   'HWater': 18.85,
#   '% change': 0.0},
#  'NKE': {'price': 97.01,
#   '200DA': 87.703186,
#   'Value': 154021494784,
#   '50DA': 92.295425,
#   '52WH': 97.63,
#   '52WL': 66.53,
#   'HWater': 97.01,
#   '% change': 0.0},
#  'DIS': {'price': 146.1,
#   '200DA': 137.93811,
#   'Value': 321685127168,
#   '50DA': 141.052,
#   '52WH': 153.41,
#   '52WL': 100.35,
#   'HWater': 147.66,
#   '% change': -0.01067761806981521},
#  'LULU': {'price': 229.65,
#   '200DA': 192.8637,
#   'Value': 29992554496,
#   '50DA': 213.83858,
#   '52WH': 233.53,
#   '52WL': 110.71,
#   'HWater': 230.88,
#   '% change': -0.005355976485956846},
#  'CVX': {'price': 117.89,
#   '200DA': 119.861374,
#   'Value': 248011309056,
#   '50DA': 118.58572,
#   '52WH': 127.34,
#   '52WL': 100.22,
#   'HWater': 118.01,
#   '% change': -0.0010178980405463106}}

# %%
investment["BHP"]
# Out:
# {'price': 52.59,
#  '200DA': 51.900726,
#  'Value': 147693846528,
#  '50DA': 50.639427,
#  '52WH': 59.02,
#  '52WL': 45.97,
#  'HWater': 52.59,
#  '% change': 0.0}

# %%
update_investment = defaultdict()
update_investment['symbol']['HW'] = highwater
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-529c215caa86> in <module>
#       1 update_investment = defaultdict()
# ----> 2 update_investment['symbol']['HW'] = highwater
#
# KeyError: 'symbol'

# %%
from collections import defaultdict
my_dict = defaultdict(dict)
my_dict['myKey']['nestedDictKey1'] = a_value
my_dict['myKey']['nestedDictKey2'] = another_value

from collections import defaultdict
my_dict = defaultdict(dict)
my_dict['myKey']['nestedDictKey1'] = a_value
my_dict['myKey']['nestedDictKey2'] = another_value
