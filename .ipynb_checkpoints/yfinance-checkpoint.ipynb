# %% [markdown]
# # checking out the restarted updated old yahoo finance python module
# https://github.com/ranaroussi/yfinance
# https://towardsdatascience.com/best-5-free-stock-market-apis-in-2019-ad91dddec984

# %%
import yfinance as yf
import pandas as pd
import pickle
from collections import defaultdict
# methods = info

# %%
equity = yf.Ticker("lulu")
print("goofball")
# Out:
# goofball

# %% [markdown]
# ### model of dictionary we want to create

# %%
stocks = ['bhp','main','jpm','wfc','jnj','wmt','amzn','msft','vlo','arcc','nke','dis','lulu','cvx']

# %%
investment = {}
for stock in stocks:
    equity = yf.Ticker(stock)
    stock = {"price":equity.info['previousClose'], 
             "200DA":equity.info['twoHundredDayAverage'], 
             "Value":equity.info['enterpriseValue'],
             "50DA":equity.info['fiftyDayAverage'],
             "52WH":equity.info['fiftyTwoWeekHigh'],
             "52WL":equity.info["fiftyTwoWeekLow"]
             
            }
    investment[equity.info["symbol"]]=stock

# %%
investment
# Out:
# {'BHP': {'price': 53.74,
#   '200DA': 51.923286,
#   'Value': 150601465856,
#   '50DA': 50.907143,
#   '52WH': 59.02,
#   '52WL': 45.97},
#  'MAIN': {'price': 43.35,
#   '200DA': 42.3485,
#   'Value': 3757166848,
#   '50DA': 42.884,
#   '52WH': 44.35,
#   '52WL': 31.95},
#  'JPM': {'price': 138.02,
#   '200DA': 117.22557,
#   'Value': 156577087488,
#   '50DA': 130.202,
#   '52WH': 138.83,
#   '52WL': 91.11},
#  'WFC': {'price': 54.36,
#   '200DA': 48.706215,
#   'Value': 246722035712,
#   '50DA': 53.35743,
#   '52WH': 54.75,
#   '52WL': 43.02},
#  'JNJ': {'price': 141.34,
#   '200DA': 133.55078,
#   'Value': 383306366976,
#   '50DA': 134.6603,
#   '52WH': 145.38,
#   '52WL': 121},
#  'WMT': {'price': 119,
#   '200DA': 114.32743,
#   'Value': 412282814464,
#   '50DA': 119.10114,
#   '52WH': 125.38,
#   '52WL': 85.78},
#  'AMZN': {'price': 1760.33,
#   '200DA': 1818.4432,
#   'Value': 898200502272,
#   '50DA': 1769.3295,
#   '52WH': 2035.8,
#   '52WL': 1307},
#  'MSFT': {'price': 153.24,
#   '200DA': 139.02315,
#   'Value': 1106250825728,
#   '50DA': 147.86858,
#   '52WH': 154.6,
#   '52WL': 93.96},
#  'VLO': {'price': 94.53,
#   '200DA': 85.31607,
#   'Value': 48038002688,
#   '50DA': 97.81371,
#   '52WH': 101.99,
#   '52WL': 68.81},
#  'ARCC': {'price': 18.6,
#   '200DA': 18.435715,
#   'Value': 14628622336,
#   '50DA': 18.648285,
#   '52WH': 19.28,
#   '52WL': 14.5},
#  'NKE': {'price': 97.72,
#   '200DA': 87.84243,
#   'Value': 154880065536,
#   '50DA': 92.49486,
#   '52WH': 98.18,
#   '52WL': 66.53},
#  'DIS': {'price': 146.88,
#   '200DA': 138.07721,
#   'Value': 321558970368,
#   '50DA': 141.96114,
#   '52WH': 153.41,
#   '52WL': 100.35},
#  'LULU': {'price': 224.47,
#   '200DA': 193.3775,
#   'Value': 29317726208,
#   '50DA': 215.20428,
#   '52WH': 235.5,
#   '52WL': 110.71},
#  'CVX': {'price': 118.81,
#   '200DA': 119.82793,
#   'Value': 245988081664,
#   '50DA': 118.56457,
#   '52WH': 127.34,
#   '52WL': 100.22}}

# %%
pd.DataFrame(investment).T
# Out:
#         price        200DA         Value         50DA     52WH     52WL
# BHP     53.74    51.923286  1.506015e+11    50.907143    59.02    45.97
# MAIN    43.35    42.348500  3.757167e+09    42.884000    44.35    31.95
# JPM    138.02   117.225570  1.565771e+11   130.202000   138.83    91.11
# WFC     54.36    48.706215  2.467220e+11    53.357430    54.75    43.02
# JNJ    141.34   133.550780  3.833064e+11   134.660300   145.38   121.00
# WMT    119.00   114.327430  4.122828e+11   119.101140   125.38    85.78
# AMZN  1760.33  1818.443200  8.982005e+11  1769.329500  2035.80  1307.00
# MSFT   153.24   139.023150  1.106251e+12   147.868580   154.60    93.96
# VLO     94.53    85.316070  4.803800e+10    97.813710   101.99    68.81
# ARCC    18.60    18.435715  1.462862e+10    18.648285    19.28    14.50
# NKE     97.72    87.842430  1.548801e+11    92.494860    98.18    66.53
# DIS    146.88   138.077210  3.215590e+11   141.961140   153.41   100.35
# LULU   224.47   193.377500  2.931773e+10   215.204280   235.50   110.71
# CVX    118.81   119.827930  2.459881e+11   118.564570   127.34   100.22

# %%
class Investment():
    def __init__(self, symbol):
        self.symbol = symbol
        self.equity = yf.Ticker(self.symbol)
        self.grab_price = self.equity.info['previousClose']

# %%
# import pickle
# for stock in stocks:
#     stock = Investment(stock)
#     price = (stock.grab_price)
#     symbol = stock.symbol
#     print(price)
#     pickling_on = open(f"{symbol}.pickle","wb")
#     pickle.dump(price, pickling_on)
#     pickling_on.close()
#     pickle_off = open(f"{symbol}.pickle","rb")
#     highwater = pickle.load(pickle_off)
#     print(highwater)

# %%
# import pickle
# for stock in stocks:
#     stock = Investment(stock)
#     price = (stock.grab_price)
#     symbol = stock.symbol
#     print(symbol)
    
    
#     pickle_off = open("price.pickle","rb")
#     highwater = pickle.load(pickle_off)
#     if price > highwater:
    
#         pickling_on = open("price.pickle","wb")
#         pickle.dump(price, pickling_on)
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
#     else:
    
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
#         print(f"Last price is {(highwater - price)/highwater:.2%} below the highwater")

# %%
# import pickle
# for stock in stocks:
#     stock = Investment(stock)
#     price = stock.grab_price
#     symbol = stock.symbol
    
#     pickle_off = open(f"{symbol}.pickle","rb")
#     highwater = pickle.load(pickle_off)
#     if price > highwater:
    
#         pickling_on = open(f"{symbol}.pickle","wb")
#         pickle.dump(price, pickling_on)
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
    
#     else:
    
#         pickling_on.close()
#         print(f"The previous close for {stock.symbol} is {price} the highwater is {highwater}")
#         print(f"Last price is {(highwater - price)/highwater:.2%} below the highwater")
#         print(" ")

# %%
# import pickle

# for stock in stocks:
#     stock = Investment(stock)
#     price = stock.grab_price
#     symbol = stock.symbol
#     hw_dict = {}
#     delta_dict = {}
#     upperSymbol = symbol.upper()
#     print(f"This is the upperSymbol {upperSymbol}")
#     print(f"This is the symbol {symbol}")
    
    
    
#     with open(f"{symbol}.pickle","rb") as pickle_off:
#         highwater = pickle.load(pickle_off)
        
        
#         if price > highwater:
    
#             with open(f"{symbol}.pickle","wb") as pickling_on:
#                 pickle.dump(price, pickling_on)
                
            
            
            
#             print(f"The previous close for {stock.symbol} is ${price:,.2f}. The highwater mark is ${highwater:,.2f}")
#             print(" ")
#         else:   
#             print(f"The previous close for {stock.symbol} is ${price:,.2f}. The highwater mark is ${highwater:,.2f}")
#             print(f"Last price is {(highwater - price)/highwater:.2%} below the highwater mark")
#             print(" ")
            
#     hw_dict['HWater'] = highwater
#     investment[upperSymbol].update( hw_dict )
#     delta = (price - highwater) / price
#     delta_dict['% change'] = delta
#     investment[upperSymbol].update(delta_dict)

# %%
import pickle

for stock in stocks:
    stock = Investment(stock)
    price = stock.grab_price
    symbol = stock.symbol
    hw_dict = {}
    delta_dict = {}
    upperSymbol = symbol.upper()
    
    try:
        
        with open(f"{symbol}.pickle","rb") as pickle_off:
            highwater = pickle.load(pickle_off)
#     except:
#         print("No file!  Let's create one")
        
    except:
        print(f"No file for {symbol}!  Let's create one")
        with open(f"{symbol}.pickle","wb") as pickling_on:
                pickle.dump(price, pickling_on)
                highwater = price
                
#     except:
#         print("We have a problem creating a new file")
        
        
    if price > highwater:
    
        with open(f"{symbol}.pickle","wb") as pickling_on:
            pickle.dump(price, pickling_on)
                
            
            
            
            print(f"The previous close for {stock.symbol} is ${price:,.2f}. The highwater mark is ${highwater:,.2f}")
            print(" ")
    else:   
        print(f"The previous close for {stock.symbol} is ${price:,.2f}. The highwater mark is ${highwater:,.2f}")
        print(f"Last price is {(highwater - price)/highwater:.2%} below the highwater mark")
        print(" ")
            
    hw_dict['HWater'] = highwater
    investment[upperSymbol].update( hw_dict )
    delta = (price - highwater) / price
    delta_dict['% change'] = delta
    investment[upperSymbol].update(delta_dict)
# Out:
# The previous close for bhp is $53.74. The highwater mark is $53.74
# Last price is 0.00% below the highwater mark
#
# The previous close for main is $43.35. The highwater mark is $43.35
# Last price is 0.00% below the highwater mark
#
# The previous close for jpm is $138.02. The highwater mark is $138.02
# Last price is 0.00% below the highwater mark
#
# The previous close for wfc is $54.36. The highwater mark is $54.36
# Last price is 0.00% below the highwater mark
#
# The previous close for jnj is $141.34. The highwater mark is $141.34
# Last price is 0.00% below the highwater mark
#
# The previous close for wmt is $119.00. The highwater mark is $119.14
# Last price is 0.12% below the highwater mark
#
# The previous close for amzn is $1,760.33. The highwater mark is $1,760.33
# Last price is 0.00% below the highwater mark
#
# The previous close for msft is $153.24. The highwater mark is $153.24
# Last price is 0.00% below the highwater mark
#
# The previous close for vlo is $94.53. The highwater mark is $94.57
# Last price is 0.04% below the highwater mark
#
# The previous close for arcc is $18.60. The highwater mark is $18.85
# Last price is 1.33% below the highwater mark
#
# The previous close for nke is $97.72. The highwater mark is $97.72
# Last price is 0.00% below the highwater mark
#
# The previous close for dis is $146.88. The highwater mark is $146.88
# Last price is 0.00% below the highwater mark
#
# The previous close for lulu is $224.47. The highwater mark is $229.65
# Last price is 2.26% below the highwater mark
#
# The previous close for cvx is $118.81. The highwater mark is $118.81
# Last price is 0.00% below the highwater mark

# %%
hw_dict
# Out:
# {'HWater': 118.81}

# %%
investment
# Out:
# {'BHP': {'price': 53.74,
#   '200DA': 51.923286,
#   'Value': 150601465856,
#   '50DA': 50.907143,
#   '52WH': 59.02,
#   '52WL': 45.97,
#   'HWater': 53.74,
#   '% change': 0.0},
#  'MAIN': {'price': 43.35,
#   '200DA': 42.3485,
#   'Value': 3757166848,
#   '50DA': 42.884,
#   '52WH': 44.35,
#   '52WL': 31.95,
#   'HWater': 43.35,
#   '% change': 0.0},
#  'JPM': {'price': 138.02,
#   '200DA': 117.22557,
#   'Value': 156577087488,
#   '50DA': 130.202,
#   '52WH': 138.83,
#   '52WL': 91.11,
#   'HWater': 138.02,
#   '% change': 0.0},
#  'WFC': {'price': 54.36,
#   '200DA': 48.706215,
#   'Value': 246722035712,
#   '50DA': 53.35743,
#   '52WH': 54.75,
#   '52WL': 43.02,
#   'HWater': 54.36,
#   '% change': 0.0},
#  'JNJ': {'price': 141.34,
#   '200DA': 133.55078,
#   'Value': 383306366976,
#   '50DA': 134.6603,
#   '52WH': 145.38,
#   '52WL': 121,
#   'HWater': 141.34,
#   '% change': 0.0},
#  'WMT': {'price': 119,
#   '200DA': 114.32743,
#   'Value': 412282814464,
#   '50DA': 119.10114,
#   '52WH': 125.38,
#   '52WL': 85.78,
#   'HWater': 119.14,
#   '% change': -0.001176470588235299},
#  'AMZN': {'price': 1760.33,
#   '200DA': 1818.4432,
#   'Value': 898200502272,
#   '50DA': 1769.3295,
#   '52WH': 2035.8,
#   '52WL': 1307,
#   'HWater': 1760.33,
#   '% change': 0.0},
#  'MSFT': {'price': 153.24,
#   '200DA': 139.02315,
#   'Value': 1106250825728,
#   '50DA': 147.86858,
#   '52WH': 154.6,
#   '52WL': 93.96,
#   'HWater': 153.24,
#   '% change': 0.0},
#  'VLO': {'price': 94.53,
#   '200DA': 85.31607,
#   'Value': 48038002688,
#   '50DA': 97.81371,
#   '52WH': 101.99,
#   '52WL': 68.81,
#   'HWater': 94.57,
#   '% change': -0.00042314609118789844},
#  'ARCC': {'price': 18.6,
#   '200DA': 18.435715,
#   'Value': 14628622336,
#   '50DA': 18.648285,
#   '52WH': 19.28,
#   '52WL': 14.5,
#   'HWater': 18.85,
#   '% change': -0.013440860215053762},
#  'NKE': {'price': 97.72,
#   '200DA': 87.84243,
#   'Value': 154880065536,
#   '50DA': 92.49486,
#   '52WH': 98.18,
#   '52WL': 66.53,
#   'HWater': 97.72,
#   '% change': 0.0},
#  'DIS': {'price': 146.88,
#   '200DA': 138.07721,
#   'Value': 321558970368,
#   '50DA': 141.96114,
#   '52WH': 153.41,
#   '52WL': 100.35,
#   'HWater': 146.88,
#   '% change': 0.0},
#  'LULU': {'price': 224.47,
#   '200DA': 193.3775,
#   'Value': 29317726208,
#   '50DA': 215.20428,
#   '52WH': 235.5,
#   '52WL': 110.71,
#   'HWater': 229.65,
#   '% change': -0.02307658038936164},
#  'CVX': {'price': 118.81,
#   '200DA': 119.82793,
#   'Value': 245988081664,
#   '50DA': 118.56457,
#   '52WH': 127.34,
#   '52WL': 100.22,
#   'HWater': 118.81,
#   '% change': 0.0}}

# %%
# def write_to_pickle_file(filename, an_object):
#     with open(filename, 'wb') as file:
#         pickle.dump(an_object, file)

# %%
# def write_to_pickle_file("stockhighwater.pickle", an_object):
#     with open(filename, 'wb') as file:
#         pickle.dump(an_object, file)

# %%
# import pickle
# magic = {1:"A",2:"B",3:"C",4:"D",5:"E"}
# pickling_on = open("Emp.pickle","wb")
# pickle.dump(magic, pickling_on)
# pickling_on.close()

# %%
# pickle_off = open("Emp.pickle","rb")
# magic = pickle.load(pickle_off)
# print(magic)

# %%
pd.DataFrame(investment)
# Out:
#                    BHP          MAIN           JPM           WFC  \
# price     5.374000e+01  4.335000e+01  1.380200e+02  5.436000e+01
# 200DA     5.192329e+01  4.234850e+01  1.172256e+02  4.870622e+01
# Value     1.506015e+11  3.757167e+09  1.565771e+11  2.467220e+11
# 50DA      5.090714e+01  4.288400e+01  1.302020e+02  5.335743e+01
# 52WH      5.902000e+01  4.435000e+01  1.388300e+02  5.475000e+01
# 52WL      4.597000e+01  3.195000e+01  9.111000e+01  4.302000e+01
# HWater    5.374000e+01  4.335000e+01  1.380200e+02  5.436000e+01
# % change  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                    JNJ           WMT          AMZN          MSFT  \
# price     1.413400e+02  1.190000e+02  1.760330e+03  1.532400e+02
# 200DA     1.335508e+02  1.143274e+02  1.818443e+03  1.390231e+02
# Value     3.833064e+11  4.122828e+11  8.982005e+11  1.106251e+12
# 50DA      1.346603e+02  1.191011e+02  1.769330e+03  1.478686e+02
# 52WH      1.453800e+02  1.253800e+02  2.035800e+03  1.546000e+02
# 52WL      1.210000e+02  8.578000e+01  1.307000e+03  9.396000e+01
# HWater    1.413400e+02  1.191400e+02  1.760330e+03  1.532400e+02
# % change  0.000000e+00 -1.176471e-03  0.000000e+00  0.000000e+00
#
#                    VLO          ARCC           NKE           DIS  \
# price     9.453000e+01  1.860000e+01  9.772000e+01  1.468800e+02
# 200DA     8.531607e+01  1.843571e+01  8.784243e+01  1.380772e+02
# Value     4.803800e+10  1.462862e+10  1.548801e+11  3.215590e+11
# 50DA      9.781371e+01  1.864829e+01  9.249486e+01  1.419611e+02
# 52WH      1.019900e+02  1.928000e+01  9.818000e+01  1.534100e+02
# 52WL      6.881000e+01  1.450000e+01  6.653000e+01  1.003500e+02
# HWater    9.457000e+01  1.885000e+01  9.772000e+01  1.468800e+02
# % change -4.231461e-04 -1.344086e-02  0.000000e+00  0.000000e+00
#
#                   LULU           CVX
# price     2.244700e+02  1.188100e+02
# 200DA     1.933775e+02  1.198279e+02
# Value     2.931773e+10  2.459881e+11
# 50DA      2.152043e+02  1.185646e+02
# 52WH      2.355000e+02  1.273400e+02
# 52WL      1.107100e+02  1.002200e+02
# HWater    2.296500e+02  1.188100e+02
# % change -2.307658e-02  0.000000e+00

# %%
investment
# Out:
# {'BHP': {'price': 53.74,
#   '200DA': 51.923286,
#   'Value': 150601465856,
#   '50DA': 50.907143,
#   '52WH': 59.02,
#   '52WL': 45.97,
#   'HWater': 53.74,
#   '% change': 0.0},
#  'MAIN': {'price': 43.35,
#   '200DA': 42.3485,
#   'Value': 3757166848,
#   '50DA': 42.884,
#   '52WH': 44.35,
#   '52WL': 31.95,
#   'HWater': 43.35,
#   '% change': 0.0},
#  'JPM': {'price': 138.02,
#   '200DA': 117.22557,
#   'Value': 156577087488,
#   '50DA': 130.202,
#   '52WH': 138.83,
#   '52WL': 91.11,
#   'HWater': 138.02,
#   '% change': 0.0},
#  'WFC': {'price': 54.36,
#   '200DA': 48.706215,
#   'Value': 246722035712,
#   '50DA': 53.35743,
#   '52WH': 54.75,
#   '52WL': 43.02,
#   'HWater': 54.36,
#   '% change': 0.0},
#  'JNJ': {'price': 141.34,
#   '200DA': 133.55078,
#   'Value': 383306366976,
#   '50DA': 134.6603,
#   '52WH': 145.38,
#   '52WL': 121,
#   'HWater': 141.34,
#   '% change': 0.0},
#  'WMT': {'price': 119,
#   '200DA': 114.32743,
#   'Value': 412282814464,
#   '50DA': 119.10114,
#   '52WH': 125.38,
#   '52WL': 85.78,
#   'HWater': 119.14,
#   '% change': -0.001176470588235299},
#  'AMZN': {'price': 1760.33,
#   '200DA': 1818.4432,
#   'Value': 898200502272,
#   '50DA': 1769.3295,
#   '52WH': 2035.8,
#   '52WL': 1307,
#   'HWater': 1760.33,
#   '% change': 0.0},
#  'MSFT': {'price': 153.24,
#   '200DA': 139.02315,
#   'Value': 1106250825728,
#   '50DA': 147.86858,
#   '52WH': 154.6,
#   '52WL': 93.96,
#   'HWater': 153.24,
#   '% change': 0.0},
#  'VLO': {'price': 94.53,
#   '200DA': 85.31607,
#   'Value': 48038002688,
#   '50DA': 97.81371,
#   '52WH': 101.99,
#   '52WL': 68.81,
#   'HWater': 94.57,
#   '% change': -0.00042314609118789844},
#  'ARCC': {'price': 18.6,
#   '200DA': 18.435715,
#   'Value': 14628622336,
#   '50DA': 18.648285,
#   '52WH': 19.28,
#   '52WL': 14.5,
#   'HWater': 18.85,
#   '% change': -0.013440860215053762},
#  'NKE': {'price': 97.72,
#   '200DA': 87.84243,
#   'Value': 154880065536,
#   '50DA': 92.49486,
#   '52WH': 98.18,
#   '52WL': 66.53,
#   'HWater': 97.72,
#   '% change': 0.0},
#  'DIS': {'price': 146.88,
#   '200DA': 138.07721,
#   'Value': 321558970368,
#   '50DA': 141.96114,
#   '52WH': 153.41,
#   '52WL': 100.35,
#   'HWater': 146.88,
#   '% change': 0.0},
#  'LULU': {'price': 224.47,
#   '200DA': 193.3775,
#   'Value': 29317726208,
#   '50DA': 215.20428,
#   '52WH': 235.5,
#   '52WL': 110.71,
#   'HWater': 229.65,
#   '% change': -0.02307658038936164},
#  'CVX': {'price': 118.81,
#   '200DA': 119.82793,
#   'Value': 245988081664,
#   '50DA': 118.56457,
#   '52WH': 127.34,
#   '52WL': 100.22,
#   'HWater': 118.81,
#   '% change': 0.0}}

# %%
investment["BHP"]
# Out:
# {'price': 53.74,
#  '200DA': 51.923286,
#  'Value': 150601465856,
#  '50DA': 50.907143,
#  '52WH': 59.02,
#  '52WL': 45.97,
#  'HWater': 53.74,
#  '% change': 0.0}

# %%
update_investment = defaultdict()
update_investment['symbol']['HW'] = highwater
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-529c215caa86> in <module>
#       1 update_investment = defaultdict()
# ----> 2 update_investment['symbol']['HW'] = highwater
#
# KeyError: 'symbol'

# %%
from collections import defaultdict
my_dict = defaultdict(dict)
my_dict['myKey']['nestedDictKey1'] = a_value
my_dict['myKey']['nestedDictKey2'] = another_value

from collections import defaultdict
my_dict = defaultdict(dict)
my_dict['myKey']['nestedDictKey1'] = a_value
my_dict['myKey']['nestedDictKey2'] = another_value
